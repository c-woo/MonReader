# %% [markdown]
# # MonReader

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, load_img
from skimage.io import imread
from skimage.transform import rescale, resize, rotate

# %% [markdown]
# I will be attempting to create a neural network that is able to determine whether or not a page is being flipped from a series of images.

# %%
## create variables for image locations on computer

train = './images/training'
train_f = './images/training/flip'
train_nf = './images/training/notflip'

test = './images/testing'
test_f = './images/testing/flip'
test_nf = './images/testing/notflip'

# %%
print('Number of Training flip pictures: ', len(os.listdir(train_f)))
print('Number of Training not flip pictures: ', len(os.listdir(train_nf)))
print('Number of Testing flip pictures: ', len(os.listdir(test_f)))
print('Number of Testing not flip pictures: ', len(os.listdir(test_nf)))
# Out:
# Number of Training flip pictures:  1162
# Number of Training not flip pictures:  1230
# Number of Testing flip pictures:  290
# Number of Testing not flip pictures:  307

# %%
## get image vectors from image files and append them to a list

train_flip = []
train_notflip = []
test_flip = []
test_notflip = []

for img in os.listdir(train_f):
    train_flip.append(imread(f'./images/training/flip/{img}'))
    
for img in os.listdir(train_nf):
    train_notflip.append(imread(f'./images/training/notflip/{img}'))
                                
for img in os.listdir(test_f):
    test_flip.append(imread(f'./images/testing/flip/{img}'))
    
for img in os.listdir(test_nf):
    test_notflip.append(imread(f'./images/testing/notflip/{img}'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14812/3656344814.py in <module>
#       7
#       8 for img in os.listdir(train_f):
# ----> 9     train_flip.append(imread(f'./images/training/flip/{img}'))
#      10
#      11 for img in os.listdir(train_nf):
#
# ~\anaconda3\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# ~\anaconda3\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# ~\anaconda3\lib\site-packages\skimage\io\_plugins\imageio_plugin.py in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# ~\anaconda3\lib\site-packages\imageio\core\functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# ~\anaconda3\lib\site-packages\imageio\core\functions.py in get_reader(uri, format, mode, **kwargs)
#     184
#     185     # Return its reader object
# --> 186     return format.get_reader(request)
#     187
#     188
#
# ~\anaconda3\lib\site-packages\imageio\core\format.py in get_reader(self, request)
#     168                 "Format %s cannot read in %s mode" % (self.name, modename)
#     169             )
# --> 170         return self.Reader(self, request)
#     171
#     172     def get_writer(self, request):
#
# ~\anaconda3\lib\site-packages\imageio\core\format.py in __init__(self, format, request)
#     219             self._request = request
#     220             # Open the reader/writer
# --> 221             self._open(**self.request.kwargs.copy())
#     222
#     223         @property
#
# ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py in _open(self, pilmode, as_gray, exifrotate)
#     427     class Reader(PillowFormat.Reader):
#     428         def _open(self, pilmode=None, as_gray=False, exifrotate=True):
# --> 429             return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#     430
#     431         def _get_file(self):
#
# ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py in _open(self, pilmode, as_gray)
#     133             if self._im.palette and self._im.palette.dirty:
#     134                 self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 135             pil_try_read(self._im)
#     136             # Store args
#     137             self._kwargs = dict(
#
# ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py in pil_try_read(im)
#     667     try:
#     668         # this will raise an IOError if the file is not readable
# --> 669         im.getdata()[0]
#     670     except IOError as e:
#     671         site = "http://pillow.readthedocs.io/en/latest/installation.html"
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in getdata(self, band)
#    1321         """
#    1322
# -> 1323         self.load()
#    1324         if band is not None:
#    1325             return self.im.getband(band)
#
# ~\anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     253
#     254                             b = b + s
# --> 255                             n, err_code = decoder.decode(b)
#     256                             if n < 0:
#     257                                 break
#
# KeyboardInterrupt:

# %%
testpic = train_flip[0]
plt.imshow(testpic)

# %% [markdown]
# We can see that our image is

# %%
testpic.shape
# Out:
# (1920, 1080, 3)

# %%
cropped = testpic[100:1550]
plt.imshow(cropped)

# %%
cropped.shape
# Out:
# (1450, 1080, 3)

# %%
cropped[0]
# Out:
# array([[130, 127, 110],
#        [130, 127, 110],
#        [131, 128, 111],
#        ...,
#        [155, 147, 134],
#        [156, 148, 135],
#        [156, 148, 135]], dtype=uint8)

# %%
train_flip_test = [rescale(x[100:1550], 0.25, multichannel=True) for x in train_flip]
train_notflip_test = [rescale(x[100:1550], 0.25, multichannel=True) for x in train_flip]

# %%
plt.imshow(rescale(cropped, 0.25, multichannel=True))

# %%
train_flip = [resize(rescale(x[100:1550], 0.25, multichannel=True), (150, 150)) for x in train_flip]
train_notflip = [resize(rescale(x[100:1550], 0.25, multichannel=True), (150, 150)) for x in train_notflip]
test_flip = [resize(rescale(x[100:1550], 0.25, multichannel=True), (150, 150)) for x in test_flip]
test_notflip = [resize(rescale(x[100:1550], 0.25, multichannel=True), (150, 150)) for x in test_notflip]

# %%
training_data = []
testing_data = []

for label in [train_notflip, train_flip]:
    for img in label:
        if label == train_notflip:
            training_data.append([img, 0])
        else:
            training_data.append([img, 1])

for label in [test_notflip, test_flip]:
    for img in label:
        if label == test_notflip:
            testing_data.append([img, 0])
        else:
            testing_data.append([img, 1])

# %%
random.shuffle(training_data)
random.shuffle(testing_data)

# %%
X_train, X_test, y_train, y_test = [], [], [], []

for features, label in training_data:
    X_train.append(features)
    y_train.append(label)
    
for features, label in testing_data:
    X_test.append(features)
    y_test.append(label)
    
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
from tensorflow.keras.applications import * #Efficient Net included here
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
import shutil
from sklearn import model_selection
from tqdm import tqdm
from tensorflow.keras import optimizers
import tensorflow as tf

# %%
conv_base = EfficientNetB5(weights="imagenet", include_top=False, input_shape=(150, 150, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalMaxPooling2D())
#avoid overfitting
model.add(layers.Dropout(rate=0.2))
# Set NUMBER_OF_CLASSES to the number of your final predictions.
model.add(layers.Dense(1, activation="sigmoid"))
conv_base.trainable = False

# %%
X_train[0].shape
# Out:
# (150, 150, 3)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer='adam',
    metrics=["acc"],
)

# %%
model.fit(np.array(X_train), y_train, epochs=20)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 124s 2s/step - loss: 1.7707 - acc: 0.5038
# Epoch 2/20
# 75/75 [==============================] - 118s 2s/step - loss: 1.6062 - acc: 0.4958
# Epoch 3/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.4581 - acc: 0.5134
# Epoch 4/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.4790 - acc: 0.4941
# Epoch 5/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.3779 - acc: 0.5054
# Epoch 6/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.3234 - acc: 0.5130
# Epoch 7/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.2014 - acc: 0.5017
# Epoch 8/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.3580 - acc: 0.5163
# Epoch 9/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.2393 - acc: 0.4858
# Epoch 10/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.2823 - acc: 0.4941
# Epoch 11/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.3369 - acc: 0.4979
# Epoch 12/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.1805 - acc: 0.5071
# Epoch 13/20
# 75/75 [==============================] - 112s 1s/step - loss: 1.2290 - acc: 0.4799
# Epoch 14/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.0586 - acc: 0.5063
# Epoch 15/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.0666 - acc: 0.4837
# Epoch 16/20
# 75/75 [==============================] - 111s 1s/step - loss: 0.9298 - acc: 0.5063
# Epoch 17/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.0802 - acc: 0.5021
# Epoch 18/20
# 75/75 [==============================] - 111s 1s/step - loss: 0.9384 - acc: 0.4979
# Epoch 19/20
# 75/75 [==============================] - 27324s 369s/step - loss: 0.9463 - acc: 0.5088
# Epoch 20/20
# 75/75 [==============================] - 111s 1s/step - loss: 0.9782 - acc: 0.4900

# %%
enetb6 = EfficientNetB6(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

model_train = models.Sequential()
model_train.add(enetb6)
model_train.add(layers.GlobalMaxPooling2D())
model_train.add(layers.Dropout(0.3))
model_train.add(layers.Dense(1, activation='sigmoid'))
enetb6.trainable = True

model_train.compile(loss='binary_crossentropy', 
                    optimizer=optimizers.RMSprop(lr=1e-5), 
                    metrics=['acc'])

# %%
model_train.fit(np.array(X_train), y_train, epochs=20)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 120s 1s/step - loss: 2.6465 - acc: 0.5067
# Epoch 2/20
# 75/75 [==============================] - 109s 1s/step - loss: 2.0166 - acc: 0.4967
# Epoch 3/20
# 75/75 [==============================] - 112s 1s/step - loss: 2.0504 - acc: 0.4992
# Epoch 4/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.9900 - acc: 0.5163
# Epoch 5/20
# 75/75 [==============================] - 111s 1s/step - loss: 1.9291 - acc: 0.5050
# Epoch 6/20
# 75/75 [==============================] - 111s 1s/step - loss: 2.0325 - acc: 0.5100
# Epoch 7/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0280 - acc: 0.4895
# Epoch 8/20
# 75/75 [==============================] - 110s 1s/step - loss: 1.9282 - acc: 0.5059
# Epoch 9/20
# 75/75 [==============================] - 110s 1s/step - loss: 1.9716 - acc: 0.5029
# Epoch 10/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0572 - acc: 0.4946
# Epoch 11/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0314 - acc: 0.4946
# Epoch 12/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0310 - acc: 0.5079
# Epoch 13/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0139 - acc: 0.4979
# Epoch 14/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0204 - acc: 0.4908
# Epoch 15/20
# 75/75 [==============================] - 110s 1s/step - loss: 1.9708 - acc: 0.5096
# Epoch 16/20
# 75/75 [==============================] - 110s 1s/step - loss: 1.9978 - acc: 0.4908
# Epoch 17/20
# 75/75 [==============================] - 110s 1s/step - loss: 2.0330 - acc: 0.5046
# Epoch 18/20
# 18/75 [======>.......................] - ETA: 1:24 - loss: 1.9845 - acc: 0.5069

# %% [markdown]
# # TEST

# %%
efficientNet

# %%
train_generator = ImageDataGenerator(rescale=1./255,                                     
                                     zoom_range=.2, 
                                     shear_range=0.2,
                                     height_shift_range=.2,
                                     rotation_range=90).flow_from_directory(
                    train,
                    target_size=(150, 150),
                    batch_size=32,
                    class_mode='binary')
# Out:
# Found 2392 images belonging to 2 classes.

# %%
train_images, train_labels = next(train_generator)

# %%
flip = []
notflip = []

for num in range(25):
    if train_labels[num] == 0:
        flip.append(train_images[num]) 
    else:
        notflip.append(train_images[num])

# %%
plt.figure(figsize=(15, 6))
for n in range(4):
    plt.subplot(1, 4, n+1)
    plt.title('flip')
    plt.imshow(flip[n]);

# %%
plt.figure(figsize=(15, 6))
for n in range(4):
    plt.subplot(1, 4, n+1)
    plt.title('notflip')
    plt.imshow(notflip[n+3]);

# %%
enetb6 = EfficientNetB6(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

model = models.Sequential()
model.add(enetb6)
model.add(layers.GlobalMaxPooling2D())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='sigmoid'))
enetb6.trainable = False

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['acc'])

# %%
model.fit_generator(train_generator,
                    steps_per_epoch=75,
                    epochs=20)
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_14812/2531297495.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator,
# Epoch 1/20
# 75/75 [==============================] - 182s 2s/step - loss: 2.6699 - acc: 0.4891
# Epoch 2/20
# 75/75 [==============================] - 171s 2s/step - loss: 2.2683 - acc: 0.4954
# Epoch 3/20
# 75/75 [==============================] - 161s 2s/step - loss: 2.2107 - acc: 0.5017
# Epoch 4/20
# 75/75 [==============================] - 160s 2s/step - loss: 2.2999 - acc: 0.4941
# Epoch 5/20
# 75/75 [==============================] - 153s 2s/step - loss: 2.0751 - acc: 0.4992
# Epoch 6/20
# 75/75 [==============================] - 153s 2s/step - loss: 1.8608 - acc: 0.5067
# Epoch 7/20
# 75/75 [==============================] - 154s 2s/step - loss: 1.8469 - acc: 0.4858
# Epoch 8/20
# 75/75 [==============================] - 153s 2s/step - loss: 1.7427 - acc: 0.4912
# Epoch 9/20
# 75/75 [==============================] - 153s 2s/step - loss: 1.6218 - acc: 0.4950
# Epoch 10/20
# 75/75 [==============================] - 152s 2s/step - loss: 1.8332 - acc: 0.4883
# Epoch 11/20
# 75/75 [==============================] - 153s 2s/step - loss: 1.5821 - acc: 0.4649
# Epoch 12/20
# 75/75 [==============================] - 153s 2s/step - loss: 1.3862 - acc: 0.5130
# Epoch 13/20
# 75/75 [==============================] - 148s 2s/step - loss: 1.3379 - acc: 0.4983
# Epoch 14/20
# 75/75 [==============================] - 142s 2s/step - loss: 1.2311 - acc: 0.4954
# Epoch 15/20
# 75/75 [==============================] - 142s 2s/step - loss: 1.2060 - acc: 0.5096
# Epoch 16/20
# 75/75 [==============================] - 142s 2s/step - loss: 1.2140 - acc: 0.5121
# Epoch 17/20
# 75/75 [==============================] - 143s 2s/step - loss: 1.0611 - acc: 0.5205
# Epoch 18/20
# 75/75 [==============================] - 141s 2s/step - loss: 1.1610 - acc: 0.4929
# Epoch 19/20
# 75/75 [==============================] - 141s 2s/step - loss: 1.1748 - acc: 0.5004
# Epoch 20/20
# 75/75 [==============================] - 141s 2s/step - loss: 1.1268 - acc: 0.4908

# %%
enetb6_train = EfficientNetB6(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

model_train = models.Sequential()
model_train.add(enetb6_train)
model_train.add(layers.GlobalMaxPooling2D())
model_train.add(layers.Dropout(0.3))
model_train.add(layers.Dense(1, activation='sigmoid'))
enetb6_train.trainable = True

model_train.compile(loss='binary_crossentropy', 
                    optimizer='adam', 
                    metrics=['acc'])

# %%
model_train.fit_generator(train_generator,
                          steps_per_epoch=75,
                          epochs=20)
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_14812/2667981781.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_train.fit_generator(train_generator,
# Epoch 1/20
# 75/75 [==============================] - 615s 8s/step - loss: 0.7077 - acc: 0.7283
# Epoch 2/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.2338 - acc: 0.9114
# Epoch 3/20
# 75/75 [==============================] - 601s 8s/step - loss: 0.1637 - acc: 0.9423
# Epoch 4/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.1277 - acc: 0.9511
# Epoch 5/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0955 - acc: 0.9645
# Epoch 6/20
# 75/75 [==============================] - 617s 8s/step - loss: 0.1132 - acc: 0.9590
# Epoch 7/20
# 75/75 [==============================] - 620s 8s/step - loss: 0.0896 - acc: 0.9724
# Epoch 8/20
# 75/75 [==============================] - 604s 8s/step - loss: 0.0505 - acc: 0.9820
# Epoch 9/20
# 75/75 [==============================] - 604s 8s/step - loss: 0.0554 - acc: 0.9824
# Epoch 10/20
# 75/75 [==============================] - 597s 8s/step - loss: 0.0586 - acc: 0.9799
# Epoch 11/20
# 75/75 [==============================] - 596s 8s/step - loss: 0.0711 - acc: 0.9770
# Epoch 12/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0594 - acc: 0.9795
# Epoch 13/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0457 - acc: 0.9833
# Epoch 14/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0527 - acc: 0.9849
# Epoch 15/20
# 75/75 [==============================] - 596s 8s/step - loss: 0.0444 - acc: 0.9879
# Epoch 16/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0622 - acc: 0.9808
# Epoch 17/20
# 75/75 [==============================] - 596s 8s/step - loss: 0.0344 - acc: 0.9895
# Epoch 18/20
# 75/75 [==============================] - 595s 8s/step - loss: 0.0398 - acc: 0.9870
# Epoch 19/20
# 75/75 [==============================] - 596s 8s/step - loss: 0.0308 - acc: 0.9912
# Epoch 20/20
# 75/75 [==============================] - 624s 8s/step - loss: 0.0271 - acc: 0.9895
